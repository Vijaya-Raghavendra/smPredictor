# %%
from src.dataHandler import DataLoaderAndSaver
from src.model import StockPredictor

# %%
dataloader = DataLoaderAndSaver()

# fetching "1d" data for "5y"
dataloader.fetchAndSaveData("1d", "5y")
dataloader.processAndSaveData("1d")

# fetching "5m" data for "6m"
dataloader.fetchAndSaveData("5m", "1mo")
dataloader.processAndSaveData("5m")

# %%
model = StockPredictor()
xTrain, yTrain, xTest, yTest = model.prepareData(["Open", "Close", "Volume", "High", "Low"], 2, "Close", "ITC", "5m")

# %%
losses = model.trainModel(xTrain, yTrain, 15)
# Out:
# Epoch 1/15 - Loss: 0.2734, MAE: 0.2549
# Epoch 2/15 - Loss: 0.0636, MAE: 0.2033
# Epoch 3/15 - Loss: 0.0368, MAE: 0.1750
# Epoch 4/15 - Loss: 0.0296, MAE: 0.1566
# Epoch 5/15 - Loss: 0.0229, MAE: 0.1434
# Epoch 6/15 - Loss: 0.0192, MAE: 0.1339
# Epoch 7/15 - Loss: 0.0158, MAE: 0.1258
# Epoch 8/15 - Loss: 0.0168, MAE: 0.1197
# Epoch 9/15 - Loss: 0.0163, MAE: 0.1147
# Epoch 10/15 - Loss: 0.0168, MAE: 0.1106
# Epoch 11/15 - Loss: 0.0163, MAE: 0.1072
# Epoch 12/15 - Loss: 0.0155, MAE: 0.1042
# Epoch 13/15 - Loss: 0.0144, MAE: 0.1016
# Epoch 14/15 - Loss: 0.0133, MAE: 0.0993
# Epoch 15/15 - Loss: 0.0120, MAE: 0.0971

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 8))
plt.plot([i for i in range(1, len(losses) + 1)], losses, marker = "o")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Epoch vs Loss")
# Out:
# Text(0.5, 1.0, 'Epoch vs Loss')
